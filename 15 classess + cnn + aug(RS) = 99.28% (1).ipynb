# %%
# https://www.kaggle.com/modojj/asl-classifier-using-keras

# %%
import numpy as np
import pandas as pd
import os
import keras
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
print(os.listdir("/Users/fadhlihajar/Desktop/Capstone/ArSL1"))
# Out:
# Using TensorFlow backend.
# ['test', 'train']

# %%
train_dir = '/Users/fadhlihajar/Desktop/Capstone/ArSL1/train'
test_dir = '/Users/fadhlihajar/Desktop/Capstone/ArSL1/test'

# %%
 def load_unique():
    size_img = 64,64 
    images_for_plot = []
    labels_for_plot = []
    for folder in os.listdir(train_dir):
        for file in os.listdir(train_dir + '/' + folder):
            filepath = train_dir + '/' + folder + '/' + file
            image = cv2.imread(filepath)
            final_img = cv2.resize(image, size_img)
            final_img = cv2.cvtColor(final_img, cv2.COLOR_BGR2RGB)
            images_for_plot.append(final_img)
            labels_for_plot.append(folder)
            break
    return images_for_plot, labels_for_plot

images_for_plot, labels_for_plot = load_unique()
print("unique_labels = ", labels_for_plot)

fig = plt.figure(figsize = (15,15))
def plot_images(fig, image, label, row, col, index):
    fig.add_subplot(row, col, index)
    plt.axis('off')
    plt.imshow(image)
    plt.title(label)
    return

image_index = 0
row = 5
col = 6
for i in range(1,(row*col)):
    plot_images(fig, images_for_plot[image_index], labels_for_plot[image_index], row, col, i)
    image_index = image_index + 1
plt.show()
# Out:
# unique_labels =  ['bb', 'dha', 'dhad', 'ain', 'ya', 'seen', 'sheen', 'haa', 'fa', 'meem', 'la', 'nun', 'kaaf', 'aleff', 'taa']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-55de454599e1> in <module>
#      29 col = 6
#      30 for i in range(1,(row*col)):
# ---> 31    plot_images(fig, images_for_plot[image_index], labels_for_plot[image_index], row, col, i)
#      32    image_index = image_index + 1
#      33 plt.show()
#
# IndexError: list index out of range

# %%
labels_dict = {'bb':0,'dha':1,'dhad':2,'ain':3,'ya':4,'seen':5,'sheen':6,'haa':7,'fa':8,'meem':9,'la':10,'nun':11,'kaaf':12,
                   'aleff':13,'taa':14}

def load_data():
    
    # Loads data and preprocess. Returns train and test data along with labels.
    
    images = []
    labels = []
    size = 64,64
    print("LOADING DATA FROM : ",end = "")
    for folder in os.listdir(train_dir):
        print(folder, end = ' | ')
        for image in os.listdir(train_dir + "/" + folder):
            temp_img = cv2.imread(train_dir + '/' + folder + '/' + image)
            temp_img = cv2.resize(temp_img, size)
            images.append(temp_img)
            labels.append(labels_dict[folder])
    
    images = np.array(images)
    images = images.astype('float32')/255.0
    
    labels = keras.utils.to_categorical(labels)
    
    X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size = 0.05)
    
    print()
    print('Loaded', len(X_train),'images for training,','Train data shape =',X_train.shape)
    print('Loaded', len(X_test),'images for testing','Test data shape =',X_test.shape)
    
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = load_data()
# Out:
# LOADING DATA FROM : bb | dha | dhad | ain | ya | seen | sheen | haa | fa | meem | la | nun | kaaf | aleff | taa |
# Loaded 21701 images for training, Train data shape = (21701, 64, 64, 3)
# Loaded 1143 images for testing Test data shape = (1143, 64, 64, 3)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (21701, 64, 64, 3)
# (1143, 64, 64, 3)
# (21701, 15)
# (1143, 15)

# %%
from matplotlib import pyplot

# %%
# create a grid of 3x3 images
for i in range(0, 9):
	pyplot.subplot(330 + 1 + i)
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the plot
pyplot.show()

# %%
# Actual dataset
for i in range(0,9):
  pyplot.subplot(330+1+i)
  pyplot.imshow(X_train[i], cmap = pyplot.get_cmap('gray'))
pyplot.show()

# %% [markdown]
# ## Random Shifts

# %%
# reshape to be [samples][width][height][channels]
X_train = X_train.reshape((X_train.shape[0], 64, 64, 3))
X_test = X_test.reshape((X_test.shape[0], 64, 64, 3))
# convert from int to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# define data preparation
shift = 0.2
datagen = ImageDataGenerator(width_shift_range=shift, height_shift_range=shift)
# fit parameters from data
datagen.fit(X_train)
# configure batch size and retrieve one batch of images
for X_batch, y_batch in datagen.flow(X_train, Y_train, batch_size=9):
	# create a grid of 3x3 images
	for i in range(0, 9):
		pyplot.subplot(330 + 1 + i)
		pyplot.imshow(X_batch[i], cmap=pyplot.get_cmap('gray'))
	# show the plot
	pyplot.show()
	break

# %% [markdown]
# # AUG + CNN

# %%
def create_model():
    
    model = Sequential()
    
    model.add(Conv2D(16, kernel_size = [3,3], padding = 'same', activation = 'relu', input_shape = (64,64,3)))
    model.add(Conv2D(32, kernel_size = [3,3], padding = 'same', activation = 'relu'))
    model.add(MaxPool2D(pool_size = [3,3]))
    
    model.add(Conv2D(32, kernel_size = [3,3], padding = 'same', activation = 'relu'))
    model.add(Conv2D(64, kernel_size = [3,3], padding = 'same', activation = 'relu'))
    model.add(MaxPool2D(pool_size = [3,3]))
    
    model.add(Conv2D(128, kernel_size = [3,3], padding = 'same', activation = 'relu'))
    model.add(Conv2D(256, kernel_size = [3,3], padding = 'same', activation = 'relu'))
    model.add(MaxPool2D(pool_size = [3,3]))
    
    model.add(BatchNormalization())
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(512, activation = 'relu', kernel_regularizer = regularizers.l2(0.001)))
    model.add(Dense(15, activation = 'sigmoid'))
    
    model.compile(optimizer = 'adam', loss = keras.losses.categorical_crossentropy, metrics = ["accuracy"])
    
    print("MODEL CREATED")
    model.summary()
    
    return model

def fit_model():
    model_hist = model.fit(X_train, Y_train, batch_size = 128, epochs = 200, validation_split = 0.1)
    return model_hist

# %%
model = create_model()
# Out:
# MODEL CREATED
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        448
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 21, 21, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 21, 21, 32)        9248
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 15)                7695
# =================================================================
# Total params: 935,375
# Trainable params: 934,863
# Non-trainable params: 512
# _________________________________________________________________

# %%
curr_model_hist = fit_model()
# Out:
# Train on 19530 samples, validate on 2171 samples
# Epoch 1/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: 1.2179 - accuracy: 0.7585 - val_loss: 2.0262 - val_accuracy: 0.8333
# Epoch 2/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: 0.4964 - accuracy: 0.9546 - val_loss: 0.8459 - val_accuracy: 0.9691
# Epoch 3/200
# 19530/19530 [==============================] - 6764s 346ms/step - loss: 0.3354 - accuracy: 0.9749 - val_loss: 0.2992 - val_accuracy: 0.9797
# Epoch 4/200
# 19530/19530 [==============================] - 50171s 3s/step - loss: 0.2419 - accuracy: 0.9821 - val_loss: 0.2609 - val_accuracy: 0.9705
# Epoch 5/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.1863 - accuracy: 0.9841 - val_loss: 0.1969 - val_accuracy: 0.9770
# Epoch 6/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.1398 - accuracy: 0.9899 - val_loss: 0.1474 - val_accuracy: 0.9807
# Epoch 7/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.1073 - accuracy: 0.9907 - val_loss: 0.1236 - val_accuracy: 0.9839
# Epoch 8/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0899 - accuracy: 0.9923 - val_loss: 0.1245 - val_accuracy: 0.9793
# Epoch 9/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: 0.0861 - accuracy: 0.9912 - val_loss: 0.1204 - val_accuracy: 0.9797
# Epoch 10/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0806 - accuracy: 0.9921 - val_loss: 0.1199 - val_accuracy: 0.9825
# Epoch 11/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0764 - accuracy: 0.9926 - val_loss: 0.0946 - val_accuracy: 0.9880
# Epoch 12/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0725 - accuracy: 0.9939 - val_loss: 0.1022 - val_accuracy: 0.9839
# Epoch 13/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0674 - accuracy: 0.9942 - val_loss: 0.1264 - val_accuracy: 0.9774
# Epoch 14/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0775 - accuracy: 0.9922 - val_loss: 0.1030 - val_accuracy: 0.9885
# Epoch 15/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0830 - accuracy: 0.9914 - val_loss: 0.1602 - val_accuracy: 0.9760
# Epoch 16/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0785 - accuracy: 0.9934 - val_loss: 0.0947 - val_accuracy: 0.9880
# Epoch 17/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0560 - accuracy: 0.9967 - val_loss: 0.0730 - val_accuracy: 0.9903
# Epoch 18/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0571 - accuracy: 0.9947 - val_loss: 0.1038 - val_accuracy: 0.9825
# Epoch 19/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0578 - accuracy: 0.9951 - val_loss: 0.0916 - val_accuracy: 0.9866
# Epoch 20/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0729 - accuracy: 0.9930 - val_loss: 0.1121 - val_accuracy: 0.9830
# Epoch 21/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0690 - accuracy: 0.9948 - val_loss: 0.0933 - val_accuracy: 0.9889
# Epoch 22/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0630 - accuracy: 0.9956 - val_loss: 0.1074 - val_accuracy: 0.9830
# Epoch 23/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0549 - accuracy: 0.9968 - val_loss: 0.0669 - val_accuracy: 0.9922
# Epoch 24/200
# 19530/19530 [==============================] - 73s 4ms/step - loss: 0.0401 - accuracy: 0.9973 - val_loss: 0.1395 - val_accuracy: 0.9691
# Epoch 25/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: 0.0366 - accuracy: 0.9980 - val_loss: 0.0596 - val_accuracy: 0.9922
# Epoch 26/200
# 19530/19530 [==============================] - 291s 15ms/step - loss: 0.0457 - accuracy: 0.9957 - val_loss: 0.0901 - val_accuracy: 0.9899
# Epoch 27/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: 0.0946 - accuracy: 0.9901 - val_loss: 0.1563 - val_accuracy: 0.9830
# Epoch 28/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0913 - accuracy: 0.9939 - val_loss: 0.0812 - val_accuracy: 0.9931
# Epoch 29/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: 0.0518 - accuracy: 0.9980 - val_loss: 0.0531 - val_accuracy: 0.9954
# Epoch 30/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: 0.0295 - accuracy: 0.9991 - val_loss: 0.0475 - val_accuracy: 0.9931
# Epoch 31/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0313 - accuracy: 0.9975 - val_loss: 0.0719 - val_accuracy: 0.9899
# Epoch 32/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0616 - accuracy: 0.9943 - val_loss: 0.0882 - val_accuracy: 0.9926
# Epoch 33/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: 0.0744 - accuracy: 0.9941 - val_loss: 0.0906 - val_accuracy: 0.9922
# Epoch 34/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: 0.0531 - accuracy: 0.9975 - val_loss: 0.0600 - val_accuracy: 0.9936
# Epoch 35/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: 0.0337 - accuracy: 0.9985 - val_loss: 0.0624 - val_accuracy: 0.9912
# Epoch 36/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: 0.0248 - accuracy: 0.9990 - val_loss: 0.0451 - val_accuracy: 0.9945
# Epoch 37/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0202 - accuracy: 0.9994 - val_loss: 0.0340 - val_accuracy: 0.9954
# Epoch 38/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0123 - accuracy: 0.9998 - val_loss: 0.0294 - val_accuracy: 0.9954
# Epoch 39/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0161 - accuracy: 0.9990 - val_loss: 0.0488 - val_accuracy: 0.9936
# Epoch 40/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.1215 - accuracy: 0.9878 - val_loss: 0.2050 - val_accuracy: 0.9779
# Epoch 41/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.1149 - accuracy: 0.9937 - val_loss: 0.1040 - val_accuracy: 0.9926
# Epoch 42/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0663 - accuracy: 0.9969 - val_loss: 0.0775 - val_accuracy: 0.9926
# Epoch 43/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0483 - accuracy: 0.9978 - val_loss: 0.0677 - val_accuracy: 0.9936
# Epoch 44/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0350 - accuracy: 0.9982 - val_loss: 0.0590 - val_accuracy: 0.9936
# Epoch 45/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0430 - accuracy: 0.9975 - val_loss: 0.0607 - val_accuracy: 0.9926
# Epoch 46/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0301 - accuracy: 0.9988 - val_loss: 0.0491 - val_accuracy: 0.9945
# Epoch 47/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0184 - accuracy: 0.9997 - val_loss: 0.0294 - val_accuracy: 0.9949
# Epoch 48/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0107 - accuracy: 0.9999 - val_loss: 0.0247 - val_accuracy: 0.9959
# Epoch 49/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 0.0192 - val_accuracy: 0.9972
# Epoch 50/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: 0.0074 - accuracy: 0.9998 - val_loss: 0.0271 - val_accuracy: 0.9949
# Epoch 51/200
# 19530/19530 [==============================] - 79s 4ms/step - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.0300 - val_accuracy: 0.9945
# Epoch 52/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0227 - accuracy: 0.9981 - val_loss: 0.1253 - val_accuracy: 0.9779
# Epoch 53/200
# 19530/19530 [==============================] - 93s 5ms/step - loss: 0.1698 - accuracy: 0.9845 - val_loss: 0.1783 - val_accuracy: 0.9876
# Epoch 54/200
# 19530/19530 [==============================] - 93s 5ms/step - loss: 0.1058 - accuracy: 0.9960 - val_loss: 0.1057 - val_accuracy: 0.9908
# Epoch 55/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0643 - accuracy: 0.9977 - val_loss: 0.0693 - val_accuracy: 0.9940
# Epoch 56/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0373 - accuracy: 0.9985 - val_loss: 0.0481 - val_accuracy: 0.9931
# Epoch 57/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0284 - accuracy: 0.9990 - val_loss: 0.0376 - val_accuracy: 0.9959
# Epoch 58/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0166 - accuracy: 0.9999 - val_loss: 0.0268 - val_accuracy: 0.9972
# Epoch 59/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0135 - accuracy: 0.9993 - val_loss: 0.0321 - val_accuracy: 0.9954
# Epoch 60/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0149 - accuracy: 0.9996 - val_loss: 0.0375 - val_accuracy: 0.9940
# Epoch 61/200
# 19530/19530 [==============================] - 1490s 76ms/step - loss: 0.0457 - accuracy: 0.9959 - val_loss: 0.0831 - val_accuracy: 0.9931
# Epoch 62/200
# 19530/19530 [==============================] - 94s 5ms/step - loss: 0.0462 - accuracy: 0.9975 - val_loss: 0.0810 - val_accuracy: 0.9912
# Epoch 63/200
# 19530/19530 [==============================] - 95s 5ms/step - loss: 0.0550 - accuracy: 0.9960 - val_loss: 0.0872 - val_accuracy: 0.9936
# Epoch 64/200
# 19530/19530 [==============================] - 94s 5ms/step - loss: 0.0722 - accuracy: 0.9952 - val_loss: 0.0972 - val_accuracy: 0.9926
# Epoch 65/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: 0.0459 - accuracy: 0.9987 - val_loss: 0.0721 - val_accuracy: 0.9931
# Epoch 66/200
# 19530/19530 [==============================] - 87s 4ms/step - loss: 0.0270 - accuracy: 0.9995 - val_loss: 0.0414 - val_accuracy: 0.9954
# Epoch 67/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0150 - accuracy: 0.9999 - val_loss: 0.0266 - val_accuracy: 0.9963
# Epoch 68/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: 0.0089 - accuracy: 0.9999 - val_loss: 0.0227 - val_accuracy: 0.9968
# Epoch 69/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0068 - accuracy: 0.9999 - val_loss: 0.0216 - val_accuracy: 0.9959
# Epoch 70/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0057 - accuracy: 0.9998 - val_loss: 0.0250 - val_accuracy: 0.9945
# Epoch 71/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: 0.0105 - accuracy: 0.9996 - val_loss: 0.0346 - val_accuracy: 0.9949
# Epoch 72/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: 0.0227 - accuracy: 0.9976 - val_loss: 0.2098 - val_accuracy: 0.9595
# Epoch 73/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.3906 - val_loss: nan - val_accuracy: 0.0562
# Epoch 74/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 75/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 76/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 77/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 78/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 79/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 80/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 81/200
# 19530/19530 [==============================] - 1116s 57ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 82/200
# 19530/19530 [==============================] - 74s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 83/200
# 19530/19530 [==============================] - 77s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 84/200
# 19530/19530 [==============================] - 84s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 85/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 86/200
# 19530/19530 [==============================] - 92s 5ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 87/200
# 19530/19530 [==============================] - 299s 15ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 88/200
# 19530/19530 [==============================] - 93s 5ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 89/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 90/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 91/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 92/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 93/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 94/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 95/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 96/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 97/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 98/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 99/200
# 19530/19530 [==============================] - 73s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 100/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 101/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 102/200
# 19530/19530 [==============================] - 71s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 103/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 104/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 105/200
# 19530/19530 [==============================] - 70s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 106/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 107/200
# 19530/19530 [==============================] - 71s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 108/200
# 19530/19530 [==============================] - 71s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 109/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 110/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 111/200
# 19530/19530 [==============================] - 71s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 112/200
# 19530/19530 [==============================] - 70s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 113/200
# 19530/19530 [==============================] - 72s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 114/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 115/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 116/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 117/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 118/200
# 19530/19530 [==============================] - 72s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 119/200
# 19530/19530 [==============================] - 70s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 120/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 121/200
# 19530/19530 [==============================] - 2465s 126ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 122/200
# 19530/19530 [==============================] - 338s 17ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 123/200
# 19530/19530 [==============================] - 3353s 172ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 124/200
# 19530/19530 [==============================] - 131s 7ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 125/200
# 19530/19530 [==============================] - 122s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 126/200
# 19530/19530 [==============================] - 122s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 127/200
# 19530/19530 [==============================] - 122s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 128/200
# 19530/19530 [==============================] - 123s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 129/200
# 19530/19530 [==============================] - 125s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 130/200
# 19530/19530 [==============================] - 125s 6ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 131/200
# 19530/19530 [==============================] - 2251s 115ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 132/200
# 19530/19530 [==============================] - 3101s 159ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 133/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 134/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 135/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 136/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 137/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 138/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 139/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 140/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 141/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 142/200
# 19530/19530 [==============================] - 60s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 143/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 144/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 145/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 146/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 147/200
# 19530/19530 [==============================] - 61s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 148/200
# 19530/19530 [==============================] - 62s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 149/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 150/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 151/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 152/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 153/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 154/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 155/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 156/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 157/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 158/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 159/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 160/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 161/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 162/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 163/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 164/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 165/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 166/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 167/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 168/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 169/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 170/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 171/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 172/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 173/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 174/200
# 19530/19530 [==============================] - 69s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 175/200
# 19530/19530 [==============================] - 71s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 176/200
# 19530/19530 [==============================] - 70s 4ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 177/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 178/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 179/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 180/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 181/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 182/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 183/200
# 19530/19530 [==============================] - 67s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 184/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 185/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 186/200
# 19530/19530 [==============================] - 68s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 187/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 188/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 189/200
# 19530/19530 [==============================] - 65s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 190/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 191/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 192/200
# 19530/19530 [==============================] - 460s 24ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 193/200
# 19530/19530 [==============================] - 60s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 194/200
# 19530/19530 [==============================] - 60s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 195/200
# 19530/19530 [==============================] - 2645s 135ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 196/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 197/200
# 19530/19530 [==============================] - 66s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 198/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 199/200
# 19530/19530 [==============================] - 64s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562
# Epoch 200/200
# 19530/19530 [==============================] - 63s 3ms/step - loss: nan - accuracy: 0.0669 - val_loss: nan - val_accuracy: 0.0562

# %%
if curr_model_hist:
    print('Final Accuracy: {:.2f}%'.format(curr_model_hist.history['accuracy'][4] * 100))
    print('Validation Set Accuracy: {:.2f}%'.format(curr_model_hist.history['accuracy'][4] * 100))
# Out:
# Final Accuracy: 98.41%
# Validation Set Accuracy: 98.41%

# %%
plt.plot(curr_model_hist.history['accuracy'])
plt.plot(curr_model_hist.history['val_accuracy'])
plt.legend(['Train', 'Test'], loc='lower right')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

plt.plot(curr_model_hist.history['loss'])
plt.plot(curr_model_hist.history['val_loss'])
plt.legend(['Training', 'Validation'], loc = 'upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
